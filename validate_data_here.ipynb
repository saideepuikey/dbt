# %%
import duckdb
import pandas as pd

# %%
sql_query = '''

    SELECT
        *
    FROM
        bronze_parking_violation
    WHERE
        summons_number IS NOT NULL


'''

with duckdb.connect("data/nyc_parking_violations.db") as con:
    display(con.sql(sql_query).df())
# Out:
#        summons_number registration_state plate_type issue_date  \
# 0          9010912681                 CA        PAS 2022-10-11
# 1          4858762841                 NY        PAS 2023-08-21
# 2          4854645684                 FL        PAS 2023-07-26
# 3          9044582707                 NY        PAS 2023-04-10
# 4          9041503330                 NY        PAS 2023-03-21
# ...               ...                ...        ...        ...
# 99995      9069356715                 NY        COM 2023-08-07
# 99996      4802425399                 NY        OMS 2022-09-25
# 99997      4809109689                 NY        ORG 2022-10-28
# 99998      4834558370                 NY        PAS 2023-04-04
# 99999      4837284462                 NY        PAS 2023-04-21
#
#        violation_code vehicle_body_type vehicle_make issuing_agency  \
# 0                  17              SUBN         FORD              T
# 1                  36              4DSD        HONDA              V
# 2                  36                UT          BMW              V
# 3                  21              SUBN        SUBAR              T
# 4                  21              4DSD        CHEVR              T
# ...               ...               ...          ...            ...
# 99995              21               VAN         FORD              T
# 99996              36              SUBN        CHEVR              V
# 99997              36              SUBN        NISSA              V
# 99998              36              4DSD        LEXUS              V
# 99999              36              4DSD          KIA              V
#
#        vehicle_expiration_date  violation_location  violation_precinct  \
# 0                     20220788                  50                  50
# 1                            0                <NA>                   0
# 2                            0                <NA>                   0
# 3                     20231217                  79                  79
# 4                     20250320                  26                  26
# ...                        ...                 ...                 ...
# 99995                 20240831                  30                  30
# 99996                        0                <NA>                   0
# 99997                        0                <NA>                   0
# 99998                        0                <NA>                   0
# 99999                        0                <NA>                   0
#
#        issuer_precinct  issuer_code issuer_command issuer_squad  \
# 0                   50       365910           T201            D
# 1                    0            0           None         None
# 2                    0            0           None         None
# 3                   79       370326           T301            H
# 4                   26       373097           T103            C
# ...                ...          ...            ...          ...
# 99995               30       361887           T103           II
# 99996                0            0           None         None
# 99997                0            0           None         None
# 99998                0            0           None         None
# 99999                0            0           None         None
#
#       violation_time violation_county  violation_legal_code vehicle_color  \
# 0              0825A               BX                  <NA>         BLACK
# 1              1036A               BK                  True            GY
# 2              0126P               QN                  True           WHI
# 3              0924A                K                  <NA>            GY
# 4              1155A               NY                  <NA>            BK
# ...              ...              ...                   ...           ...
# 99995          1121A               NY                  <NA>            YW
# 99996          0214P               BX                  True            WH
# 99997          0915A               MN                  True            GY
# 99998          0416P               BK                  True            BK
# 99999          0606P               ST                  True            WH
#
#        vehicle_year
# 0                 0
# 1              2003
# 2              2022
# 3              2017
# 4              2018
# ...             ...
# 99995          2016
# 99996          2021
# 99997          2020
# 99998          2002
# 99999          2020
#
# [100000 rows x 20 columns]

# %%
# sql_query_import_1 = '''
# CREATE OR REPLACE TABLE nyc_parking_violation_codes AS
# SELECT *
# FROM read_csv_auto(
#     "data/dof_parking_violation_codes.csv",
#     normalize_names=True
#     )
# '''

# sql_query_import_2 = '''
# CREATE OR REPLACE TABLE parking_violation_2023 AS
# SELECT *
# FROM read_csv_auto(
#     "data/parking_violations_issued_fiscal_year_2023_sample.csv",
#     normalize_names=True
#     )
# '''

# with duckdb.connect("data/nyc_parking_violations.db") as con:
#     con.sql(sql_query_import_1)
#     con.sql(sql_query_import_2)
